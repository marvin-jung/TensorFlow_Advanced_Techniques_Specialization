# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 958us/sample - loss: 231.0558 - y1_output_loss: 107.5837 - y2_output_loss: 122.1322 - y1_output_root_mean_squared_error: 10.3978 - y2_output_root_mean_squared_error: 11.0879 - val_loss: 63.8411 - val_y1_output_loss: 15.2730 - val_y2_output_loss: 47.0320 - val_y1_output_root_mean_squared_error: 3.9784 - val_y2_output_root_mean_squared_error: 6.9292
# Epoch 2/500
# 614/614 [==============================] - 0s 167us/sample - loss: 34.4493 - y1_output_loss: 12.9955 - y2_output_loss: 21.7827 - y1_output_root_mean_squared_error: 3.6040 - y2_output_root_mean_squared_error: 4.6325 - val_loss: 76.0335 - val_y1_output_loss: 18.3429 - val_y2_output_loss: 56.4277 - val_y1_output_root_mean_squared_error: 4.3439 - val_y2_output_root_mean_squared_error: 7.5607
# Epoch 3/500
# 614/614 [==============================] - 0s 143us/sample - loss: 31.7132 - y1_output_loss: 10.9318 - y2_output_loss: 20.6546 - y1_output_root_mean_squared_error: 3.3093 - y2_output_root_mean_squared_error: 4.5565 - val_loss: 19.9072 - val_y1_output_loss: 10.0534 - val_y2_output_loss: 10.0086 - val_y1_output_root_mean_squared_error: 3.1343 - val_y2_output_root_mean_squared_error: 3.1754
# Epoch 4/500
# 614/614 [==============================] - 0s 138us/sample - loss: 28.4093 - y1_output_loss: 10.7164 - y2_output_loss: 17.6982 - y1_output_root_mean_squared_error: 3.2583 - y2_output_root_mean_squared_error: 4.2182 - val_loss: 33.1991 - val_y1_output_loss: 15.8206 - val_y2_output_loss: 17.7217 - val_y1_output_root_mean_squared_error: 3.9534 - val_y2_output_root_mean_squared_error: 4.1916
# Epoch 5/500
# 614/614 [==============================] - 0s 141us/sample - loss: 24.7128 - y1_output_loss: 9.7895 - y2_output_loss: 14.8863 - y1_output_root_mean_squared_error: 3.1313 - y2_output_root_mean_squared_error: 3.8610 - val_loss: 22.5789 - val_y1_output_loss: 9.1338 - val_y2_output_loss: 13.1795 - val_y1_output_root_mean_squared_error: 3.0321 - val_y2_output_root_mean_squared_error: 3.6586
# Epoch 6/500
# 614/614 [==============================] - 0s 138us/sample - loss: 22.5890 - y1_output_loss: 8.8306 - y2_output_loss: 13.5789 - y1_output_root_mean_squared_error: 2.9857 - y2_output_root_mean_squared_error: 3.6979 - val_loss: 21.6548 - val_y1_output_loss: 9.7760 - val_y2_output_loss: 11.6100 - val_y1_output_root_mean_squared_error: 3.1439 - val_y2_output_root_mean_squared_error: 3.4309
# Epoch 7/500
# 614/614 [==============================] - 0s 136us/sample - loss: 22.0241 - y1_output_loss: 8.7352 - y2_output_loss: 13.0875 - y1_output_root_mean_squared_error: 2.9691 - y2_output_root_mean_squared_error: 3.6344 - val_loss: 17.1778 - val_y1_output_loss: 7.8639 - val_y2_output_loss: 9.2436 - val_y1_output_root_mean_squared_error: 2.8022 - val_y2_output_root_mean_squared_error: 3.0538
# Epoch 8/500
# 614/614 [==============================] - 0s 136us/sample - loss: 21.7221 - y1_output_loss: 8.1983 - y2_output_loss: 13.4634 - y1_output_root_mean_squared_error: 2.8539 - y2_output_root_mean_squared_error: 3.6847 - val_loss: 21.8155 - val_y1_output_loss: 11.4335 - val_y2_output_loss: 10.7013 - val_y1_output_root_mean_squared_error: 3.3519 - val_y2_output_root_mean_squared_error: 3.2527
# Epoch 9/500
# 614/614 [==============================] - 0s 136us/sample - loss: 24.5213 - y1_output_loss: 9.4260 - y2_output_loss: 15.3456 - y1_output_root_mean_squared_error: 3.0595 - y2_output_root_mean_squared_error: 3.8937 - val_loss: 19.6712 - val_y1_output_loss: 7.9695 - val_y2_output_loss: 11.6952 - val_y1_output_root_mean_squared_error: 2.8229 - val_y2_output_root_mean_squared_error: 3.4209
# Epoch 10/500
# 614/614 [==============================] - 0s 134us/sample - loss: 23.1787 - y1_output_loss: 8.6152 - y2_output_loss: 14.3851 - y1_output_root_mean_squared_error: 2.9481 - y2_output_root_mean_squared_error: 3.8063 - val_loss: 18.2332 - val_y1_output_loss: 8.2639 - val_y2_output_loss: 9.9430 - val_y1_output_root_mean_squared_error: 2.8733 - val_y2_output_root_mean_squared_error: 3.1587
# Epoch 11/500
# 614/614 [==============================] - 0s 131us/sample - loss: 20.7716 - y1_output_loss: 7.8146 - y2_output_loss: 12.7849 - y1_output_root_mean_squared_error: 2.8072 - y2_output_root_mean_squared_error: 3.5905 - val_loss: 19.2395 - val_y1_output_loss: 8.0483 - val_y2_output_loss: 11.4419 - val_y1_output_root_mean_squared_error: 2.8156 - val_y2_output_root_mean_squared_error: 3.3633
# Epoch 12/500
# 614/614 [==============================] - 0s 132us/sample - loss: 20.7202 - y1_output_loss: 7.5327 - y2_output_loss: 13.8257 - y1_output_root_mean_squared_error: 2.7305 - y2_output_root_mean_squared_error: 3.6420 - val_loss: 188.0776 - val_y1_output_loss: 32.0993 - val_y2_output_loss: 158.3232 - val_y1_output_root_mean_squared_error: 5.5910 - val_y2_output_root_mean_squared_error: 12.5227
# Epoch 13/500
# 614/614 [==============================] - 0s 132us/sample - loss: 30.6642 - y1_output_loss: 9.3671 - y2_output_loss: 21.0350 - y1_output_root_mean_squared_error: 3.0715 - y2_output_root_mean_squared_error: 4.6076 - val_loss: 15.8839 - val_y1_output_loss: 7.5441 - val_y2_output_loss: 8.4726 - val_y1_output_root_mean_squared_error: 2.7302 - val_y2_output_root_mean_squared_error: 2.9035
# Epoch 14/500
# 614/614 [==============================] - 0s 132us/sample - loss: 21.6573 - y1_output_loss: 7.6207 - y2_output_loss: 13.9488 - y1_output_root_mean_squared_error: 2.7575 - y2_output_root_mean_squared_error: 3.7488 - val_loss: 23.0839 - val_y1_output_loss: 8.8486 - val_y2_output_loss: 13.7360 - val_y1_output_root_mean_squared_error: 2.9992 - val_y2_output_root_mean_squared_error: 3.7535
# Epoch 15/500
# 614/614 [==============================] - 0s 132us/sample - loss: 17.0389 - y1_output_loss: 6.4590 - y2_output_loss: 10.5097 - y1_output_root_mean_squared_error: 2.5451 - y2_output_root_mean_squared_error: 3.2498 - val_loss: 26.6153 - val_y1_output_loss: 8.5932 - val_y2_output_loss: 17.7712 - val_y1_output_root_mean_squared_error: 2.9335 - val_y2_output_root_mean_squared_error: 4.2438
# Epoch 16/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.7816 - y1_output_loss: 5.6514 - y2_output_loss: 8.0763 - y1_output_root_mean_squared_error: 2.3821 - y2_output_root_mean_squared_error: 2.8473 - val_loss: 13.3724 - val_y1_output_loss: 6.2710 - val_y2_output_loss: 7.4111 - val_y1_output_root_mean_squared_error: 2.4666 - val_y2_output_root_mean_squared_error: 2.6997
# Epoch 17/500
# 614/614 [==============================] - 0s 132us/sample - loss: 16.2043 - y1_output_loss: 6.0764 - y2_output_loss: 10.2002 - y1_output_root_mean_squared_error: 2.4744 - y2_output_root_mean_squared_error: 3.1752 - val_loss: 26.9656 - val_y1_output_loss: 9.7830 - val_y2_output_loss: 17.4925 - val_y1_output_root_mean_squared_error: 3.1024 - val_y2_output_root_mean_squared_error: 4.1642
# Epoch 18/500
# 614/614 [==============================] - 0s 134us/sample - loss: 15.4197 - y1_output_loss: 5.6554 - y2_output_loss: 9.6784 - y1_output_root_mean_squared_error: 2.3824 - y2_output_root_mean_squared_error: 3.1215 - val_loss: 13.4645 - val_y1_output_loss: 6.2073 - val_y2_output_loss: 7.2948 - val_y1_output_root_mean_squared_error: 2.4791 - val_y2_output_root_mean_squared_error: 2.7053
# Epoch 19/500
# 614/614 [==============================] - 0s 131us/sample - loss: 14.1501 - y1_output_loss: 5.3403 - y2_output_loss: 8.7756 - y1_output_root_mean_squared_error: 2.3212 - y2_output_root_mean_squared_error: 2.9601 - val_loss: 11.7892 - val_y1_output_loss: 5.5093 - val_y2_output_loss: 6.4677 - val_y1_output_root_mean_squared_error: 2.3119 - val_y2_output_root_mean_squared_error: 2.5386
# Epoch 20/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.5728 - y1_output_loss: 4.5979 - y2_output_loss: 7.0903 - y1_output_root_mean_squared_error: 2.1085 - y2_output_root_mean_squared_error: 2.6697 - val_loss: 28.1712 - val_y1_output_loss: 9.4192 - val_y2_output_loss: 18.1541 - val_y1_output_root_mean_squared_error: 3.0983 - val_y2_output_root_mean_squared_error: 4.3095
# Epoch 21/500
# 614/614 [==============================] - 0s 133us/sample - loss: 13.3641 - y1_output_loss: 4.9573 - y2_output_loss: 8.2849 - y1_output_root_mean_squared_error: 2.2365 - y2_output_root_mean_squared_error: 2.8917 - val_loss: 11.6086 - val_y1_output_loss: 5.3027 - val_y2_output_loss: 6.4234 - val_y1_output_root_mean_squared_error: 2.2815 - val_y2_output_root_mean_squared_error: 2.5305
# Epoch 22/500
# 614/614 [==============================] - 0s 134us/sample - loss: 14.7704 - y1_output_loss: 5.1268 - y2_output_loss: 9.5809 - y1_output_root_mean_squared_error: 2.2688 - y2_output_root_mean_squared_error: 3.1021 - val_loss: 12.7420 - val_y1_output_loss: 5.1729 - val_y2_output_loss: 7.3467 - val_y1_output_root_mean_squared_error: 2.2803 - val_y2_output_root_mean_squared_error: 2.7463
# Epoch 23/500
# 614/614 [==============================] - 0s 134us/sample - loss: 11.2090 - y1_output_loss: 4.1135 - y2_output_loss: 7.0793 - y1_output_root_mean_squared_error: 2.0360 - y2_output_root_mean_squared_error: 2.6578 - val_loss: 11.9787 - val_y1_output_loss: 5.3945 - val_y2_output_loss: 6.5644 - val_y1_output_root_mean_squared_error: 2.3185 - val_y2_output_root_mean_squared_error: 2.5697
# Epoch 24/500
# 614/614 [==============================] - 0s 138us/sample - loss: 10.6744 - y1_output_loss: 3.9150 - y2_output_loss: 6.6804 - y1_output_root_mean_squared_error: 1.9842 - y2_output_root_mean_squared_error: 2.5956 - val_loss: 12.2671 - val_y1_output_loss: 5.9264 - val_y2_output_loss: 6.5537 - val_y1_output_root_mean_squared_error: 2.4024 - val_y2_output_root_mean_squared_error: 2.5487
# Epoch 25/500
# 614/614 [==============================] - 0s 151us/sample - loss: 10.0513 - y1_output_loss: 3.7698 - y2_output_loss: 6.6759 - y1_output_root_mean_squared_error: 1.9213 - y2_output_root_mean_squared_error: 2.5219 - val_loss: 73.5214 - val_y1_output_loss: 15.5507 - val_y2_output_loss: 58.5427 - val_y1_output_root_mean_squared_error: 3.9087 - val_y2_output_root_mean_squared_error: 7.6318
# Epoch 26/500
# 614/614 [==============================] - 0s 142us/sample - loss: 14.5202 - y1_output_loss: 4.8549 - y2_output_loss: 9.7274 - y1_output_root_mean_squared_error: 2.1992 - y2_output_root_mean_squared_error: 3.1119 - val_loss: 25.6533 - val_y1_output_loss: 7.1685 - val_y2_output_loss: 17.7433 - val_y1_output_root_mean_squared_error: 2.7103 - val_y2_output_root_mean_squared_error: 4.2787
# Epoch 27/500
# 614/614 [==============================] - 0s 140us/sample - loss: 11.7287 - y1_output_loss: 3.8529 - y2_output_loss: 7.9368 - y1_output_root_mean_squared_error: 1.9700 - y2_output_root_mean_squared_error: 2.8014 - val_loss: 13.9140 - val_y1_output_loss: 4.0307 - val_y2_output_loss: 9.7843 - val_y1_output_root_mean_squared_error: 1.9577 - val_y2_output_root_mean_squared_error: 3.1751
# Epoch 28/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.5381 - y1_output_loss: 3.1969 - y2_output_loss: 6.3137 - y1_output_root_mean_squared_error: 1.7942 - y2_output_root_mean_squared_error: 2.5138 - val_loss: 11.7926 - val_y1_output_loss: 3.8816 - val_y2_output_loss: 8.1804 - val_y1_output_root_mean_squared_error: 1.9387 - val_y2_output_root_mean_squared_error: 2.8344
# Epoch 29/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.8557 - y1_output_loss: 2.9695 - y2_output_loss: 5.8321 - y1_output_root_mean_squared_error: 1.7273 - y2_output_root_mean_squared_error: 2.4232 - val_loss: 12.1463 - val_y1_output_loss: 4.4159 - val_y2_output_loss: 8.0806 - val_y1_output_root_mean_squared_error: 2.0620 - val_y2_output_root_mean_squared_error: 2.8097
# Epoch 30/500
# 614/614 [==============================] - 0s 142us/sample - loss: 11.0609 - y1_output_loss: 3.6339 - y2_output_loss: 7.4136 - y1_output_root_mean_squared_error: 1.9093 - y2_output_root_mean_squared_error: 2.7231 - val_loss: 20.5025 - val_y1_output_loss: 7.2478 - val_y2_output_loss: 12.6803 - val_y1_output_root_mean_squared_error: 2.7255 - val_y2_output_root_mean_squared_error: 3.6158
# Epoch 31/500
# 614/614 [==============================] - 0s 138us/sample - loss: 10.5104 - y1_output_loss: 3.4627 - y2_output_loss: 7.3119 - y1_output_root_mean_squared_error: 1.8463 - y2_output_root_mean_squared_error: 2.6649 - val_loss: 23.7843 - val_y1_output_loss: 6.0235 - val_y2_output_loss: 18.4940 - val_y1_output_root_mean_squared_error: 2.3906 - val_y2_output_root_mean_squared_error: 4.2508
# Epoch 32/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.4430 - y1_output_loss: 2.8240 - y2_output_loss: 5.6733 - y1_output_root_mean_squared_error: 1.6788 - y2_output_root_mean_squared_error: 2.3716 - val_loss: 28.0039 - val_y1_output_loss: 7.5553 - val_y2_output_loss: 19.6971 - val_y1_output_root_mean_squared_error: 2.7864 - val_y2_output_root_mean_squared_error: 4.4989
# Epoch 33/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.3965 - y1_output_loss: 2.6478 - y2_output_loss: 5.7479 - y1_output_root_mean_squared_error: 1.6322 - y2_output_root_mean_squared_error: 2.3942 - val_loss: 10.9370 - val_y1_output_loss: 3.7527 - val_y2_output_loss: 7.1071 - val_y1_output_root_mean_squared_error: 1.9121 - val_y2_output_root_mean_squared_error: 2.6983
# Epoch 34/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.5948 - y1_output_loss: 2.5118 - y2_output_loss: 5.0673 - y1_output_root_mean_squared_error: 1.5891 - y2_output_root_mean_squared_error: 2.2515 - val_loss: 9.0241 - val_y1_output_loss: 3.3137 - val_y2_output_loss: 5.7901 - val_y1_output_root_mean_squared_error: 1.8095 - val_y2_output_root_mean_squared_error: 2.3979
# Epoch 35/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.3885 - y1_output_loss: 2.6483 - y2_output_loss: 5.8111 - y1_output_root_mean_squared_error: 1.6162 - y2_output_root_mean_squared_error: 2.4034 - val_loss: 11.8198 - val_y1_output_loss: 5.4800 - val_y2_output_loss: 6.1201 - val_y1_output_root_mean_squared_error: 2.3606 - val_y2_output_root_mean_squared_error: 2.4995
# Epoch 36/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.4058 - y1_output_loss: 2.3929 - y2_output_loss: 5.1742 - y1_output_root_mean_squared_error: 1.5490 - y2_output_root_mean_squared_error: 2.2375 - val_loss: 39.0498 - val_y1_output_loss: 8.9687 - val_y2_output_loss: 28.9564 - val_y1_output_root_mean_squared_error: 3.0445 - val_y2_output_root_mean_squared_error: 5.4572
# Epoch 37/500
# 614/614 [==============================] - 0s 142us/sample - loss: 10.6109 - y1_output_loss: 3.4299 - y2_output_loss: 7.0850 - y1_output_root_mean_squared_error: 1.8603 - y2_output_root_mean_squared_error: 2.6740 - val_loss: 13.6834 - val_y1_output_loss: 4.8076 - val_y2_output_loss: 8.5271 - val_y1_output_root_mean_squared_error: 2.2095 - val_y2_output_root_mean_squared_error: 2.9668
# Epoch 38/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.6992 - y1_output_loss: 2.3843 - y2_output_loss: 5.2697 - y1_output_root_mean_squared_error: 1.5471 - y2_output_root_mean_squared_error: 2.3034 - val_loss: 7.0986 - val_y1_output_loss: 2.9873 - val_y2_output_loss: 4.2291 - val_y1_output_root_mean_squared_error: 1.6856 - val_y2_output_root_mean_squared_error: 2.0633
# Epoch 39/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.3272 - y1_output_loss: 2.3139 - y2_output_loss: 5.0389 - y1_output_root_mean_squared_error: 1.5113 - y2_output_root_mean_squared_error: 2.2457 - val_loss: 21.8595 - val_y1_output_loss: 8.1278 - val_y2_output_loss: 13.0267 - val_y1_output_root_mean_squared_error: 2.8956 - val_y2_output_root_mean_squared_error: 3.6708
# Epoch 40/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.9978 - y1_output_loss: 2.2742 - y2_output_loss: 4.7060 - y1_output_root_mean_squared_error: 1.5144 - y2_output_root_mean_squared_error: 2.1690 - val_loss: 10.0585 - val_y1_output_loss: 3.7375 - val_y2_output_loss: 6.7827 - val_y1_output_root_mean_squared_error: 1.8745 - val_y2_output_root_mean_squared_error: 2.5582
# Epoch 41/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.7188 - y1_output_loss: 2.5238 - y2_output_loss: 5.2065 - y1_output_root_mean_squared_error: 1.5748 - y2_output_root_mean_squared_error: 2.2889 - val_loss: 8.4417 - val_y1_output_loss: 3.2658 - val_y2_output_loss: 5.2691 - val_y1_output_root_mean_squared_error: 1.7922 - val_y2_output_root_mean_squared_error: 2.2868
# Epoch 42/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.0669 - y1_output_loss: 2.7518 - y2_output_loss: 6.3009 - y1_output_root_mean_squared_error: 1.6516 - y2_output_root_mean_squared_error: 2.5178 - val_loss: 8.0456 - val_y1_output_loss: 3.0893 - val_y2_output_loss: 4.8601 - val_y1_output_root_mean_squared_error: 1.7497 - val_y2_output_root_mean_squared_error: 2.2325
# Epoch 43/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.0650 - y1_output_loss: 2.4124 - y2_output_loss: 4.6289 - y1_output_root_mean_squared_error: 1.5537 - y2_output_root_mean_squared_error: 2.1566 - val_loss: 11.6882 - val_y1_output_loss: 3.6563 - val_y2_output_loss: 7.6745 - val_y1_output_root_mean_squared_error: 1.9343 - val_y2_output_root_mean_squared_error: 2.8190
# Epoch 44/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.1482 - y1_output_loss: 2.1440 - y2_output_loss: 4.9630 - y1_output_root_mean_squared_error: 1.4710 - y2_output_root_mean_squared_error: 2.2326 - val_loss: 8.3173 - val_y1_output_loss: 3.4623 - val_y2_output_loss: 5.0799 - val_y1_output_root_mean_squared_error: 1.8237 - val_y2_output_root_mean_squared_error: 2.2342
# Epoch 45/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.6493 - y1_output_loss: 2.1151 - y2_output_loss: 4.5214 - y1_output_root_mean_squared_error: 1.4468 - y2_output_root_mean_squared_error: 2.1345 - val_loss: 7.8903 - val_y1_output_loss: 3.5439 - val_y2_output_loss: 4.4840 - val_y1_output_root_mean_squared_error: 1.8485 - val_y2_output_root_mean_squared_error: 2.1150
# Epoch 46/500
# 614/614 [==============================] - 0s 153us/sample - loss: 9.4770 - y1_output_loss: 2.9218 - y2_output_loss: 6.5495 - y1_output_root_mean_squared_error: 1.7049 - y2_output_root_mean_squared_error: 2.5633 - val_loss: 18.5631 - val_y1_output_loss: 9.6071 - val_y2_output_loss: 9.1170 - val_y1_output_root_mean_squared_error: 3.0765 - val_y2_output_root_mean_squared_error: 3.0163
# Epoch 47/500
# 614/614 [==============================] - 0s 157us/sample - loss: 7.8716 - y1_output_loss: 2.3034 - y2_output_loss: 5.5406 - y1_output_root_mean_squared_error: 1.5213 - y2_output_root_mean_squared_error: 2.3574 - val_loss: 14.6252 - val_y1_output_loss: 5.0019 - val_y2_output_loss: 10.1381 - val_y1_output_root_mean_squared_error: 2.1768 - val_y2_output_root_mean_squared_error: 3.1443
# Epoch 48/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.4411 - y1_output_loss: 1.8118 - y2_output_loss: 4.5729 - y1_output_root_mean_squared_error: 1.3512 - y2_output_root_mean_squared_error: 2.1483 - val_loss: 6.8145 - val_y1_output_loss: 2.5352 - val_y2_output_loss: 4.3420 - val_y1_output_root_mean_squared_error: 1.5726 - val_y2_output_root_mean_squared_error: 2.0836
# Epoch 49/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.9787 - y1_output_loss: 1.7637 - y2_output_loss: 4.2271 - y1_output_root_mean_squared_error: 1.3286 - y2_output_root_mean_squared_error: 2.0527 - val_loss: 12.6381 - val_y1_output_loss: 2.5484 - val_y2_output_loss: 9.8553 - val_y1_output_root_mean_squared_error: 1.5759 - val_y2_output_root_mean_squared_error: 3.1866
# Epoch 50/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.4242 - y1_output_loss: 2.0795 - y2_output_loss: 4.4019 - y1_output_root_mean_squared_error: 1.4401 - y2_output_root_mean_squared_error: 2.0857 - val_loss: 7.6468 - val_y1_output_loss: 2.4150 - val_y2_output_loss: 5.3407 - val_y1_output_root_mean_squared_error: 1.5375 - val_y2_output_root_mean_squared_error: 2.2984
# Epoch 51/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.4409 - y1_output_loss: 1.9509 - y2_output_loss: 4.5029 - y1_output_root_mean_squared_error: 1.3942 - y2_output_root_mean_squared_error: 2.1207 - val_loss: 10.3319 - val_y1_output_loss: 5.1986 - val_y2_output_loss: 5.3431 - val_y1_output_root_mean_squared_error: 2.2403 - val_y2_output_root_mean_squared_error: 2.3050
# Epoch 52/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.1061 - y1_output_loss: 1.9676 - y2_output_loss: 4.1087 - y1_output_root_mean_squared_error: 1.4092 - y2_output_root_mean_squared_error: 2.0298 - val_loss: 5.6811 - val_y1_output_loss: 2.1736 - val_y2_output_loss: 3.6578 - val_y1_output_root_mean_squared_error: 1.4374 - val_y2_output_root_mean_squared_error: 1.9013
# Epoch 53/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.5373 - y1_output_loss: 1.6306 - y2_output_loss: 3.9032 - y1_output_root_mean_squared_error: 1.2774 - y2_output_root_mean_squared_error: 1.9763 - val_loss: 7.7237 - val_y1_output_loss: 2.9237 - val_y2_output_loss: 4.6718 - val_y1_output_root_mean_squared_error: 1.7113 - val_y2_output_root_mean_squared_error: 2.1898
# Epoch 54/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.2682 - y1_output_loss: 1.9279 - y2_output_loss: 4.3885 - y1_output_root_mean_squared_error: 1.3764 - y2_output_root_mean_squared_error: 2.0913 - val_loss: 7.2138 - val_y1_output_loss: 3.2927 - val_y2_output_loss: 3.9968 - val_y1_output_root_mean_squared_error: 1.7791 - val_y2_output_root_mean_squared_error: 2.0121
# Epoch 55/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.7606 - y1_output_loss: 2.0867 - y2_output_loss: 4.6310 - y1_output_root_mean_squared_error: 1.4511 - y2_output_root_mean_squared_error: 2.1575 - val_loss: 7.3774 - val_y1_output_loss: 2.5272 - val_y2_output_loss: 4.7176 - val_y1_output_root_mean_squared_error: 1.5859 - val_y2_output_root_mean_squared_error: 2.2051
# Epoch 56/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.8345 - y1_output_loss: 2.6510 - y2_output_loss: 6.1878 - y1_output_root_mean_squared_error: 1.6258 - y2_output_root_mean_squared_error: 2.4882 - val_loss: 10.6720 - val_y1_output_loss: 4.3793 - val_y2_output_loss: 6.2232 - val_y1_output_root_mean_squared_error: 2.0900 - val_y2_output_root_mean_squared_error: 2.5108
# Epoch 57/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.4268 - y1_output_loss: 1.8428 - y2_output_loss: 4.5266 - y1_output_root_mean_squared_error: 1.3633 - y2_output_root_mean_squared_error: 2.1374 - val_loss: 5.9649 - val_y1_output_loss: 2.2172 - val_y2_output_loss: 3.6939 - val_y1_output_root_mean_squared_error: 1.4799 - val_y2_output_root_mean_squared_error: 1.9429
# Epoch 58/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.3227 - y1_output_loss: 2.7914 - y2_output_loss: 6.6891 - y1_output_root_mean_squared_error: 1.6565 - y2_output_root_mean_squared_error: 2.5649 - val_loss: 25.6170 - val_y1_output_loss: 7.4583 - val_y2_output_loss: 17.5320 - val_y1_output_root_mean_squared_error: 2.7678 - val_y2_output_root_mean_squared_error: 4.2375
# Epoch 59/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.5124 - y1_output_loss: 2.4309 - y2_output_loss: 5.0649 - y1_output_root_mean_squared_error: 1.5557 - y2_output_root_mean_squared_error: 2.2565 - val_loss: 10.7424 - val_y1_output_loss: 2.8819 - val_y2_output_loss: 7.5376 - val_y1_output_root_mean_squared_error: 1.7118 - val_y2_output_root_mean_squared_error: 2.7950
# Epoch 60/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.7525 - y1_output_loss: 1.8822 - y2_output_loss: 3.9122 - y1_output_root_mean_squared_error: 1.3669 - y2_output_root_mean_squared_error: 1.9708 - val_loss: 12.0834 - val_y1_output_loss: 3.8004 - val_y2_output_loss: 7.8974 - val_y1_output_root_mean_squared_error: 1.9770 - val_y2_output_root_mean_squared_error: 2.8592
# Epoch 61/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.3263 - y1_output_loss: 1.7128 - y2_output_loss: 3.6047 - y1_output_root_mean_squared_error: 1.3119 - y2_output_root_mean_squared_error: 1.8988 - val_loss: 6.7093 - val_y1_output_loss: 2.7032 - val_y2_output_loss: 4.0323 - val_y1_output_root_mean_squared_error: 1.6271 - val_y2_output_root_mean_squared_error: 2.0154
# Epoch 62/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.6877 - y1_output_loss: 1.8968 - y2_output_loss: 4.7425 - y1_output_root_mean_squared_error: 1.3801 - y2_output_root_mean_squared_error: 2.1870 - val_loss: 9.2461 - val_y1_output_loss: 3.3823 - val_y2_output_loss: 5.5787 - val_y1_output_root_mean_squared_error: 1.8626 - val_y2_output_root_mean_squared_error: 2.4035
# Epoch 63/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.2297 - y1_output_loss: 1.9219 - y2_output_loss: 4.2503 - y1_output_root_mean_squared_error: 1.3925 - y2_output_root_mean_squared_error: 2.0714 - val_loss: 7.0995 - val_y1_output_loss: 2.7153 - val_y2_output_loss: 4.2420 - val_y1_output_root_mean_squared_error: 1.6528 - val_y2_output_root_mean_squared_error: 2.0899
# Epoch 64/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.3195 - y1_output_loss: 1.6788 - y2_output_loss: 3.6252 - y1_output_root_mean_squared_error: 1.2994 - y2_output_root_mean_squared_error: 1.9055 - val_loss: 6.5409 - val_y1_output_loss: 2.5753 - val_y2_output_loss: 3.8163 - val_y1_output_root_mean_squared_error: 1.6164 - val_y2_output_root_mean_squared_error: 1.9819
# Epoch 65/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.1688 - y1_output_loss: 1.6203 - y2_output_loss: 3.5022 - y1_output_root_mean_squared_error: 1.2785 - y2_output_root_mean_squared_error: 1.8800 - val_loss: 4.9406 - val_y1_output_loss: 1.9190 - val_y2_output_loss: 3.0323 - val_y1_output_root_mean_squared_error: 1.3662 - val_y2_output_root_mean_squared_error: 1.7533
# Epoch 66/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.0346 - y1_output_loss: 1.7567 - y2_output_loss: 4.5076 - y1_output_root_mean_squared_error: 1.3152 - y2_output_root_mean_squared_error: 2.0748 - val_loss: 38.7166 - val_y1_output_loss: 11.3034 - val_y2_output_loss: 26.6964 - val_y1_output_root_mean_squared_error: 3.3952 - val_y2_output_root_mean_squared_error: 5.2143
# Epoch 67/500
# 614/614 [==============================] - 0s 149us/sample - loss: 7.9446 - y1_output_loss: 2.3346 - y2_output_loss: 5.5718 - y1_output_root_mean_squared_error: 1.5267 - y2_output_root_mean_squared_error: 2.3693 - val_loss: 7.4360 - val_y1_output_loss: 3.0158 - val_y2_output_loss: 4.2945 - val_y1_output_root_mean_squared_error: 1.7392 - val_y2_output_root_mean_squared_error: 2.1003
# Epoch 68/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.2158 - y1_output_loss: 1.4956 - y2_output_loss: 3.6967 - y1_output_root_mean_squared_error: 1.2272 - y2_output_root_mean_squared_error: 1.9260 - val_loss: 6.8294 - val_y1_output_loss: 2.5717 - val_y2_output_loss: 4.3795 - val_y1_output_root_mean_squared_error: 1.5737 - val_y2_output_root_mean_squared_error: 2.0864
# Epoch 69/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.3457 - y1_output_loss: 1.8168 - y2_output_loss: 4.4706 - y1_output_root_mean_squared_error: 1.3542 - y2_output_root_mean_squared_error: 2.1241 - val_loss: 5.3735 - val_y1_output_loss: 2.0358 - val_y2_output_loss: 3.4738 - val_y1_output_root_mean_squared_error: 1.3910 - val_y2_output_root_mean_squared_error: 1.8544
# Epoch 70/500
# 614/614 [==============================] - 0s 141us/sample - loss: 16.4933 - y1_output_loss: 5.2433 - y2_output_loss: 11.6082 - y1_output_root_mean_squared_error: 2.2559 - y2_output_root_mean_squared_error: 3.3770 - val_loss: 321.3066 - val_y1_output_loss: 132.6462 - val_y2_output_loss: 178.4015 - val_y1_output_root_mean_squared_error: 11.7289 - val_y2_output_root_mean_squared_error: 13.5550
# Epoch 71/500
# 614/614 [==============================] - 0s 146us/sample - loss: 22.3570 - y1_output_loss: 9.7026 - y2_output_loss: 12.4450 - y1_output_root_mean_squared_error: 3.1292 - y2_output_root_mean_squared_error: 3.5447 - val_loss: 7.0628 - val_y1_output_loss: 2.2400 - val_y2_output_loss: 5.0034 - val_y1_output_root_mean_squared_error: 1.4677 - val_y2_output_root_mean_squared_error: 2.2156
# Epoch 72/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.2070 - y1_output_loss: 1.5298 - y2_output_loss: 3.6781 - y1_output_root_mean_squared_error: 1.2402 - y2_output_root_mean_squared_error: 1.9155 - val_loss: 7.0391 - val_y1_output_loss: 2.0761 - val_y2_output_loss: 4.8404 - val_y1_output_root_mean_squared_error: 1.4392 - val_y2_output_root_mean_squared_error: 2.2289
# Epoch 73/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.9812 - y1_output_loss: 1.4056 - y2_output_loss: 3.5366 - y1_output_root_mean_squared_error: 1.1908 - y2_output_root_mean_squared_error: 1.8877 - val_loss: 5.4131 - val_y1_output_loss: 1.5648 - val_y2_output_loss: 3.7722 - val_y1_output_root_mean_squared_error: 1.2303 - val_y2_output_root_mean_squared_error: 1.9747
# Epoch 74/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.4576 - y1_output_loss: 1.1704 - y2_output_loss: 3.3549 - y1_output_root_mean_squared_error: 1.0802 - y2_output_root_mean_squared_error: 1.8141 - val_loss: 11.2696 - val_y1_output_loss: 1.5473 - val_y2_output_loss: 9.5020 - val_y1_output_root_mean_squared_error: 1.2358 - val_y2_output_root_mean_squared_error: 3.1213
# Epoch 75/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.9625 - y1_output_loss: 1.4024 - y2_output_loss: 3.5187 - y1_output_root_mean_squared_error: 1.1891 - y2_output_root_mean_squared_error: 1.8838 - val_loss: 4.1139 - val_y1_output_loss: 1.5355 - val_y2_output_loss: 2.5878 - val_y1_output_root_mean_squared_error: 1.2194 - val_y2_output_root_mean_squared_error: 1.6208
# Epoch 76/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.7621 - y1_output_loss: 1.0275 - y2_output_loss: 2.7894 - y1_output_root_mean_squared_error: 1.0052 - y2_output_root_mean_squared_error: 1.6588 - val_loss: 9.2127 - val_y1_output_loss: 2.8130 - val_y2_output_loss: 6.1474 - val_y1_output_root_mean_squared_error: 1.6964 - val_y2_output_root_mean_squared_error: 2.5169
# Epoch 77/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.3503 - y1_output_loss: 1.2222 - y2_output_loss: 3.1221 - y1_output_root_mean_squared_error: 1.1086 - y2_output_root_mean_squared_error: 1.7667 - val_loss: 8.8985 - val_y1_output_loss: 2.2331 - val_y2_output_loss: 6.4605 - val_y1_output_root_mean_squared_error: 1.5055 - val_y2_output_root_mean_squared_error: 2.5753
# Epoch 78/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.6358 - y1_output_loss: 1.2887 - y2_output_loss: 3.3869 - y1_output_root_mean_squared_error: 1.1400 - y2_output_root_mean_squared_error: 1.8265 - val_loss: 13.6386 - val_y1_output_loss: 2.6774 - val_y2_output_loss: 11.1765 - val_y1_output_root_mean_squared_error: 1.6052 - val_y2_output_root_mean_squared_error: 3.3259
# Epoch 79/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.6904 - y1_output_loss: 1.2445 - y2_output_loss: 3.4057 - y1_output_root_mean_squared_error: 1.1204 - y2_output_root_mean_squared_error: 1.8534 - val_loss: 3.7631 - val_y1_output_loss: 1.3050 - val_y2_output_loss: 2.4188 - val_y1_output_root_mean_squared_error: 1.1342 - val_y2_output_root_mean_squared_error: 1.5737
# Epoch 80/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.6473 - y1_output_loss: 0.8961 - y2_output_loss: 2.7205 - y1_output_root_mean_squared_error: 0.9494 - y2_output_root_mean_squared_error: 1.6571 - val_loss: 4.0892 - val_y1_output_loss: 1.2104 - val_y2_output_loss: 2.8164 - val_y1_output_root_mean_squared_error: 1.0880 - val_y2_output_root_mean_squared_error: 1.7045
# Epoch 81/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.4161 - y1_output_loss: 0.9379 - y2_output_loss: 2.4474 - y1_output_root_mean_squared_error: 0.9728 - y2_output_root_mean_squared_error: 1.5715 - val_loss: 3.1704 - val_y1_output_loss: 1.0835 - val_y2_output_loss: 2.0845 - val_y1_output_root_mean_squared_error: 1.0242 - val_y2_output_root_mean_squared_error: 1.4565
# Epoch 82/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.9374 - y1_output_loss: 0.9435 - y2_output_loss: 2.9912 - y1_output_root_mean_squared_error: 0.9709 - y2_output_root_mean_squared_error: 1.7305 - val_loss: 3.4737 - val_y1_output_loss: 1.2252 - val_y2_output_loss: 2.1912 - val_y1_output_root_mean_squared_error: 1.1054 - val_y2_output_root_mean_squared_error: 1.5006
# Epoch 83/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.5161 - y1_output_loss: 0.9958 - y2_output_loss: 2.5060 - y1_output_root_mean_squared_error: 0.9939 - y2_output_root_mean_squared_error: 1.5900 - val_loss: 3.5637 - val_y1_output_loss: 1.1935 - val_y2_output_loss: 2.3614 - val_y1_output_root_mean_squared_error: 1.0669 - val_y2_output_root_mean_squared_error: 1.5574
# Epoch 84/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.2767 - y1_output_loss: 0.8318 - y2_output_loss: 2.4308 - y1_output_root_mean_squared_error: 0.9119 - y2_output_root_mean_squared_error: 1.5637 - val_loss: 4.8887 - val_y1_output_loss: 1.2015 - val_y2_output_loss: 3.5654 - val_y1_output_root_mean_squared_error: 1.0972 - val_y2_output_root_mean_squared_error: 1.9196
# Epoch 85/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.4546 - y1_output_loss: 0.9453 - y2_output_loss: 2.4857 - y1_output_root_mean_squared_error: 0.9753 - y2_output_root_mean_squared_error: 1.5822 - val_loss: 3.3068 - val_y1_output_loss: 1.2005 - val_y2_output_loss: 2.0598 - val_y1_output_root_mean_squared_error: 1.0874 - val_y2_output_root_mean_squared_error: 1.4575
# Epoch 86/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.0374 - y1_output_loss: 1.0282 - y2_output_loss: 2.9975 - y1_output_root_mean_squared_error: 1.0113 - y2_output_root_mean_squared_error: 1.7363 - val_loss: 4.0673 - val_y1_output_loss: 1.6646 - val_y2_output_loss: 2.2940 - val_y1_output_root_mean_squared_error: 1.3029 - val_y2_output_root_mean_squared_error: 1.5394
# Epoch 87/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.1287 - y1_output_loss: 1.2676 - y2_output_loss: 3.8738 - y1_output_root_mean_squared_error: 1.1270 - y2_output_root_mean_squared_error: 1.9643 - val_loss: 5.9946 - val_y1_output_loss: 2.2690 - val_y2_output_loss: 3.5555 - val_y1_output_root_mean_squared_error: 1.5226 - val_y2_output_root_mean_squared_error: 1.9174
# Epoch 88/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.1057 - y1_output_loss: 1.0512 - y2_output_loss: 3.0285 - y1_output_root_mean_squared_error: 1.0254 - y2_output_root_mean_squared_error: 1.7477 - val_loss: 5.1483 - val_y1_output_loss: 1.9669 - val_y2_output_loss: 3.0400 - val_y1_output_root_mean_squared_error: 1.4156 - val_y2_output_root_mean_squared_error: 1.7733
# Epoch 89/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.7205 - y1_output_loss: 0.9204 - y2_output_loss: 2.8697 - y1_output_root_mean_squared_error: 0.9634 - y2_output_root_mean_squared_error: 1.6710 - val_loss: 6.0531 - val_y1_output_loss: 1.5997 - val_y2_output_loss: 4.3670 - val_y1_output_root_mean_squared_error: 1.2440 - val_y2_output_root_mean_squared_error: 2.1227
# Epoch 90/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.2322 - y1_output_loss: 0.8706 - y2_output_loss: 2.3495 - y1_output_root_mean_squared_error: 0.9334 - y2_output_root_mean_squared_error: 1.5366 - val_loss: 3.2103 - val_y1_output_loss: 0.9475 - val_y2_output_loss: 2.3057 - val_y1_output_root_mean_squared_error: 0.9550 - val_y2_output_root_mean_squared_error: 1.5160
# Epoch 91/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.9411 - y1_output_loss: 0.6280 - y2_output_loss: 2.3075 - y1_output_root_mean_squared_error: 0.7886 - y2_output_root_mean_squared_error: 1.5229 - val_loss: 2.6182 - val_y1_output_loss: 0.8645 - val_y2_output_loss: 1.7531 - val_y1_output_root_mean_squared_error: 0.9128 - val_y2_output_root_mean_squared_error: 1.3360
# Epoch 92/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.3187 - y1_output_loss: 0.8360 - y2_output_loss: 2.5164 - y1_output_root_mean_squared_error: 0.9087 - y2_output_root_mean_squared_error: 1.5789 - val_loss: 2.6284 - val_y1_output_loss: 0.8445 - val_y2_output_loss: 1.7562 - val_y1_output_root_mean_squared_error: 0.9100 - val_y2_output_root_mean_squared_error: 1.3417
# Epoch 93/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6148 - y1_output_loss: 0.6527 - y2_output_loss: 1.9559 - y1_output_root_mean_squared_error: 0.8087 - y2_output_root_mean_squared_error: 1.4003 - val_loss: 5.6088 - val_y1_output_loss: 1.4895 - val_y2_output_loss: 3.9326 - val_y1_output_root_mean_squared_error: 1.2356 - val_y2_output_root_mean_squared_error: 2.0204
# Epoch 94/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.5654 - y1_output_loss: 0.9181 - y2_output_loss: 2.6207 - y1_output_root_mean_squared_error: 0.9613 - y2_output_root_mean_squared_error: 1.6252 - val_loss: 2.7464 - val_y1_output_loss: 0.8520 - val_y2_output_loss: 1.9329 - val_y1_output_root_mean_squared_error: 0.9026 - val_y2_output_root_mean_squared_error: 1.3899
# Epoch 95/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.4034 - y1_output_loss: 0.9035 - y2_output_loss: 2.5512 - y1_output_root_mean_squared_error: 0.9509 - y2_output_root_mean_squared_error: 1.5809 - val_loss: 6.9872 - val_y1_output_loss: 3.1198 - val_y2_output_loss: 4.0489 - val_y1_output_root_mean_squared_error: 1.7333 - val_y2_output_root_mean_squared_error: 1.9957
# Epoch 96/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.2529 - y1_output_loss: 0.9017 - y2_output_loss: 3.3592 - y1_output_root_mean_squared_error: 0.9450 - y2_output_root_mean_squared_error: 1.8330 - val_loss: 9.2495 - val_y1_output_loss: 3.0288 - val_y2_output_loss: 5.9384 - val_y1_output_root_mean_squared_error: 1.7644 - val_y2_output_root_mean_squared_error: 2.4772
# Epoch 97/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.9000 - y1_output_loss: 0.7256 - y2_output_loss: 2.1687 - y1_output_root_mean_squared_error: 0.8549 - y2_output_root_mean_squared_error: 1.4728 - val_loss: 2.5116 - val_y1_output_loss: 0.8429 - val_y2_output_loss: 1.6111 - val_y1_output_root_mean_squared_error: 0.9212 - val_y2_output_root_mean_squared_error: 1.2896
# Epoch 98/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.5904 - y1_output_loss: 0.6296 - y2_output_loss: 1.9692 - y1_output_root_mean_squared_error: 0.7968 - y2_output_root_mean_squared_error: 1.3984 - val_loss: 4.0945 - val_y1_output_loss: 0.9119 - val_y2_output_loss: 3.0587 - val_y1_output_root_mean_squared_error: 0.9604 - val_y2_output_root_mean_squared_error: 1.7810
# Epoch 99/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.8123 - y1_output_loss: 0.6549 - y2_output_loss: 2.1412 - y1_output_root_mean_squared_error: 0.8104 - y2_output_root_mean_squared_error: 1.4682 - val_loss: 2.8813 - val_y1_output_loss: 1.0456 - val_y2_output_loss: 1.8703 - val_y1_output_root_mean_squared_error: 1.0041 - val_y2_output_root_mean_squared_error: 1.3686
# Epoch 100/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.8177 - y1_output_loss: 0.6737 - y2_output_loss: 2.1669 - y1_output_root_mean_squared_error: 0.8189 - y2_output_root_mean_squared_error: 1.4653 - val_loss: 15.9360 - val_y1_output_loss: 5.0650 - val_y2_output_loss: 11.0590 - val_y1_output_root_mean_squared_error: 2.2285 - val_y2_output_root_mean_squared_error: 3.3121
# Epoch 101/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.8477 - y1_output_loss: 0.7877 - y2_output_loss: 2.0787 - y1_output_root_mean_squared_error: 0.8878 - y2_output_root_mean_squared_error: 1.4351 - val_loss: 4.2835 - val_y1_output_loss: 1.4725 - val_y2_output_loss: 2.6700 - val_y1_output_root_mean_squared_error: 1.2307 - val_y2_output_root_mean_squared_error: 1.6640
# Epoch 102/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.4707 - y1_output_loss: 0.6579 - y2_output_loss: 1.8642 - y1_output_root_mean_squared_error: 0.7987 - y2_output_root_mean_squared_error: 1.3538 - val_loss: 4.0352 - val_y1_output_loss: 1.1326 - val_y2_output_loss: 2.8878 - val_y1_output_root_mean_squared_error: 1.0603 - val_y2_output_root_mean_squared_error: 1.7062
# Epoch 103/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.7964 - y1_output_loss: 0.9416 - y2_output_loss: 2.8550 - y1_output_root_mean_squared_error: 0.9671 - y2_output_root_mean_squared_error: 1.6915 - val_loss: 2.5830 - val_y1_output_loss: 0.9191 - val_y2_output_loss: 1.7294 - val_y1_output_root_mean_squared_error: 0.9352 - val_y2_output_root_mean_squared_error: 1.3071
# Epoch 104/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.4254 - y1_output_loss: 0.8959 - y2_output_loss: 2.5078 - y1_output_root_mean_squared_error: 0.9482 - y2_output_root_mean_squared_error: 1.5894 - val_loss: 2.7712 - val_y1_output_loss: 0.9000 - val_y2_output_loss: 1.9158 - val_y1_output_root_mean_squared_error: 0.9310 - val_y2_output_root_mean_squared_error: 1.3800
# Epoch 105/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.3607 - y1_output_loss: 0.5882 - y2_output_loss: 1.8645 - y1_output_root_mean_squared_error: 0.7536 - y2_output_root_mean_squared_error: 1.3389 - val_loss: 28.4057 - val_y1_output_loss: 7.6987 - val_y2_output_loss: 20.9086 - val_y1_output_root_mean_squared_error: 2.7565 - val_y2_output_root_mean_squared_error: 4.5615
# Epoch 106/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.1478 - y1_output_loss: 1.3940 - y2_output_loss: 3.7089 - y1_output_root_mean_squared_error: 1.1854 - y2_output_root_mean_squared_error: 1.9346 - val_loss: 2.1643 - val_y1_output_loss: 0.6981 - val_y2_output_loss: 1.4187 - val_y1_output_root_mean_squared_error: 0.8394 - val_y2_output_root_mean_squared_error: 1.2082
# Epoch 107/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.9987 - y1_output_loss: 0.6593 - y2_output_loss: 2.3620 - y1_output_root_mean_squared_error: 0.8152 - y2_output_root_mean_squared_error: 1.5278 - val_loss: 5.2424 - val_y1_output_loss: 0.8697 - val_y2_output_loss: 4.3778 - val_y1_output_root_mean_squared_error: 0.9267 - val_y2_output_root_mean_squared_error: 2.0937
# Epoch 108/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.2336 - y1_output_loss: 0.8289 - y2_output_loss: 2.4160 - y1_output_root_mean_squared_error: 0.8960 - y2_output_root_mean_squared_error: 1.5591 - val_loss: 3.0247 - val_y1_output_loss: 1.4841 - val_y2_output_loss: 1.5986 - val_y1_output_root_mean_squared_error: 1.1897 - val_y2_output_root_mean_squared_error: 1.2686
# Epoch 109/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.4188 - y1_output_loss: 0.8290 - y2_output_loss: 2.5869 - y1_output_root_mean_squared_error: 0.9141 - y2_output_root_mean_squared_error: 1.6072 - val_loss: 3.6459 - val_y1_output_loss: 0.6056 - val_y2_output_loss: 2.9337 - val_y1_output_root_mean_squared_error: 0.7814 - val_y2_output_root_mean_squared_error: 1.7422
# Epoch 110/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.5553 - y1_output_loss: 0.6169 - y2_output_loss: 1.9379 - y1_output_root_mean_squared_error: 0.7855 - y2_output_root_mean_squared_error: 1.3922 - val_loss: 4.6379 - val_y1_output_loss: 2.4700 - val_y2_output_loss: 2.1217 - val_y1_output_root_mean_squared_error: 1.5727 - val_y2_output_root_mean_squared_error: 1.4713
# Epoch 111/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.1192 - y1_output_loss: 0.7604 - y2_output_loss: 2.3911 - y1_output_root_mean_squared_error: 0.8625 - y2_output_root_mean_squared_error: 1.5412 - val_loss: 5.6961 - val_y1_output_loss: 1.7024 - val_y2_output_loss: 3.8623 - val_y1_output_root_mean_squared_error: 1.3126 - val_y2_output_root_mean_squared_error: 1.9933
# Epoch 112/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.7770 - y1_output_loss: 0.7277 - y2_output_loss: 2.0246 - y1_output_root_mean_squared_error: 0.8567 - y2_output_root_mean_squared_error: 1.4294 - val_loss: 2.0324 - val_y1_output_loss: 0.5991 - val_y2_output_loss: 1.4269 - val_y1_output_root_mean_squared_error: 0.7661 - val_y2_output_root_mean_squared_error: 1.2023
# Epoch 113/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.6827 - y1_output_loss: 0.6015 - y2_output_loss: 2.0733 - y1_output_root_mean_squared_error: 0.7761 - y2_output_root_mean_squared_error: 1.4424 - val_loss: 2.4276 - val_y1_output_loss: 0.9292 - val_y2_output_loss: 1.4934 - val_y1_output_root_mean_squared_error: 0.9456 - val_y2_output_root_mean_squared_error: 1.2383
# Epoch 114/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.3993 - y1_output_loss: 0.5341 - y2_output_loss: 1.8448 - y1_output_root_mean_squared_error: 0.7342 - y2_output_root_mean_squared_error: 1.3639 - val_loss: 2.3700 - val_y1_output_loss: 0.6153 - val_y2_output_loss: 1.7009 - val_y1_output_root_mean_squared_error: 0.7803 - val_y2_output_root_mean_squared_error: 1.3271
# Epoch 115/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.5600 - y1_output_loss: 0.6341 - y2_output_loss: 1.9392 - y1_output_root_mean_squared_error: 0.7924 - y2_output_root_mean_squared_error: 1.3900 - val_loss: 4.4871 - val_y1_output_loss: 1.6635 - val_y2_output_loss: 2.8195 - val_y1_output_root_mean_squared_error: 1.2894 - val_y2_output_root_mean_squared_error: 1.6806
# Epoch 116/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.1935 - y1_output_loss: 0.7971 - y2_output_loss: 2.4046 - y1_output_root_mean_squared_error: 0.8863 - y2_output_root_mean_squared_error: 1.5518 - val_loss: 7.1005 - val_y1_output_loss: 1.7632 - val_y2_output_loss: 5.1805 - val_y1_output_root_mean_squared_error: 1.3394 - val_y2_output_root_mean_squared_error: 2.3036
# Epoch 117/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.8998 - y1_output_loss: 0.7503 - y2_output_loss: 2.1365 - y1_output_root_mean_squared_error: 0.8650 - y2_output_root_mean_squared_error: 1.4668 - val_loss: 3.1139 - val_y1_output_loss: 1.0367 - val_y2_output_loss: 2.1213 - val_y1_output_root_mean_squared_error: 1.0032 - val_y2_output_root_mean_squared_error: 1.4518
# Epoch 118/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.2610 - y1_output_loss: 0.6987 - y2_output_loss: 1.5633 - y1_output_root_mean_squared_error: 0.8324 - y2_output_root_mean_squared_error: 1.2523 - val_loss: 1.8167 - val_y1_output_loss: 0.5126 - val_y2_output_loss: 1.2757 - val_y1_output_root_mean_squared_error: 0.7170 - val_y2_output_root_mean_squared_error: 1.1413
# Epoch 119/500
# 614/614 [==============================] - 0s 140us/sample - loss: 1.9549 - y1_output_loss: 0.4639 - y2_output_loss: 1.4784 - y1_output_root_mean_squared_error: 0.6814 - y2_output_root_mean_squared_error: 1.2209 - val_loss: 1.8907 - val_y1_output_loss: 0.5603 - val_y2_output_loss: 1.3189 - val_y1_output_root_mean_squared_error: 0.7446 - val_y2_output_root_mean_squared_error: 1.1560
# Epoch 120/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.2556 - y1_output_loss: 0.6129 - y2_output_loss: 1.6541 - y1_output_root_mean_squared_error: 0.7710 - y2_output_root_mean_squared_error: 1.2888 - val_loss: 2.9427 - val_y1_output_loss: 0.6969 - val_y2_output_loss: 2.1571 - val_y1_output_root_mean_squared_error: 0.8434 - val_y2_output_root_mean_squared_error: 1.4937
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2894 - y1_output_loss: 0.1068 - y2_output_loss: 0.1837 - y1_output_root_mean_squared_error: 0.3265 - y2_output_root_mean_squared_error: 0.4276 - val_loss: 1.0115 - val_y1_output_loss: 0.1941 - val_y2_output_loss: 0.8142 - val_y1_output_root_mean_squared_error: 0.4448 - val_y2_output_root_mean_squared_error: 0.9020
# Epoch 462/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3250 - y1_output_loss: 0.1130 - y2_output_loss: 0.2111 - y1_output_root_mean_squared_error: 0.3358 - y2_output_root_mean_squared_error: 0.4607 - val_loss: 0.6538 - val_y1_output_loss: 0.1610 - val_y2_output_loss: 0.4827 - val_y1_output_root_mean_squared_error: 0.4036 - val_y2_output_root_mean_squared_error: 0.7006
# Epoch 463/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4449 - y1_output_loss: 0.1571 - y2_output_loss: 0.2885 - y1_output_root_mean_squared_error: 0.3953 - y2_output_root_mean_squared_error: 0.5372 - val_loss: 0.8242 - val_y1_output_loss: 0.2429 - val_y2_output_loss: 0.5726 - val_y1_output_root_mean_squared_error: 0.4961 - val_y2_output_root_mean_squared_error: 0.7603
# Epoch 464/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4804 - y1_output_loss: 0.1481 - y2_output_loss: 0.3298 - y1_output_root_mean_squared_error: 0.3866 - y2_output_root_mean_squared_error: 0.5753 - val_loss: 1.0743 - val_y1_output_loss: 0.2107 - val_y2_output_loss: 0.8904 - val_y1_output_root_mean_squared_error: 0.4564 - val_y2_output_root_mean_squared_error: 0.9306
# Epoch 465/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3571 - y1_output_loss: 0.1299 - y2_output_loss: 0.2297 - y1_output_root_mean_squared_error: 0.3590 - y2_output_root_mean_squared_error: 0.4777 - val_loss: 0.8441 - val_y1_output_loss: 0.2109 - val_y2_output_loss: 0.6073 - val_y1_output_root_mean_squared_error: 0.4652 - val_y2_output_root_mean_squared_error: 0.7923
# Epoch 466/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4153 - y1_output_loss: 0.1490 - y2_output_loss: 0.2682 - y1_output_root_mean_squared_error: 0.3836 - y2_output_root_mean_squared_error: 0.5179 - val_loss: 0.9739 - val_y1_output_loss: 0.3265 - val_y2_output_loss: 0.6548 - val_y1_output_root_mean_squared_error: 0.5670 - val_y2_output_root_mean_squared_error: 0.8078
# Epoch 467/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.5143 - y1_output_loss: 0.1905 - y2_output_loss: 0.3239 - y1_output_root_mean_squared_error: 0.4368 - y2_output_root_mean_squared_error: 0.5688 - val_loss: 0.7996 - val_y1_output_loss: 0.1983 - val_y2_output_loss: 0.5792 - val_y1_output_root_mean_squared_error: 0.4502 - val_y2_output_root_mean_squared_error: 0.7726
# Epoch 468/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4008 - y1_output_loss: 0.1242 - y2_output_loss: 0.2757 - y1_output_root_mean_squared_error: 0.3525 - y2_output_root_mean_squared_error: 0.5259 - val_loss: 0.9659 - val_y1_output_loss: 0.2363 - val_y2_output_loss: 0.7230 - val_y1_output_root_mean_squared_error: 0.4860 - val_y2_output_root_mean_squared_error: 0.8542
# Epoch 469/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3385 - y1_output_loss: 0.1220 - y2_output_loss: 0.2147 - y1_output_root_mean_squared_error: 0.3507 - y2_output_root_mean_squared_error: 0.4642 - val_loss: 0.8549 - val_y1_output_loss: 0.2438 - val_y2_output_loss: 0.6132 - val_y1_output_root_mean_squared_error: 0.4900 - val_y2_output_root_mean_squared_error: 0.7841
# Epoch 470/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5311 - y1_output_loss: 0.1706 - y2_output_loss: 0.3599 - y1_output_root_mean_squared_error: 0.4108 - y2_output_root_mean_squared_error: 0.6019 - val_loss: 0.9530 - val_y1_output_loss: 0.3068 - val_y2_output_loss: 0.6179 - val_y1_output_root_mean_squared_error: 0.5642 - val_y2_output_root_mean_squared_error: 0.7967
# Epoch 471/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.6881 - y1_output_loss: 0.1914 - y2_output_loss: 0.4918 - y1_output_root_mean_squared_error: 0.4386 - y2_output_root_mean_squared_error: 0.7041 - val_loss: 0.7105 - val_y1_output_loss: 0.1679 - val_y2_output_loss: 0.5433 - val_y1_output_root_mean_squared_error: 0.4124 - val_y2_output_root_mean_squared_error: 0.7351
# Epoch 472/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3308 - y1_output_loss: 0.1170 - y2_output_loss: 0.2116 - y1_output_root_mean_squared_error: 0.3435 - y2_output_root_mean_squared_error: 0.4614 - val_loss: 0.6826 - val_y1_output_loss: 0.1383 - val_y2_output_loss: 0.5435 - val_y1_output_root_mean_squared_error: 0.3731 - val_y2_output_root_mean_squared_error: 0.7371
# Epoch 473/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3614 - y1_output_loss: 0.1131 - y2_output_loss: 0.2519 - y1_output_root_mean_squared_error: 0.3375 - y2_output_root_mean_squared_error: 0.4975 - val_loss: 0.8357 - val_y1_output_loss: 0.1543 - val_y2_output_loss: 0.6836 - val_y1_output_root_mean_squared_error: 0.3952 - val_y2_output_root_mean_squared_error: 0.8243
# Epoch 474/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4481 - y1_output_loss: 0.1546 - y2_output_loss: 0.2966 - y1_output_root_mean_squared_error: 0.3942 - y2_output_root_mean_squared_error: 0.5410 - val_loss: 0.7742 - val_y1_output_loss: 0.1628 - val_y2_output_loss: 0.5880 - val_y1_output_root_mean_squared_error: 0.4077 - val_y2_output_root_mean_squared_error: 0.7797
# Epoch 475/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3424 - y1_output_loss: 0.1294 - y2_output_loss: 0.2126 - y1_output_root_mean_squared_error: 0.3603 - y2_output_root_mean_squared_error: 0.4611 - val_loss: 0.7021 - val_y1_output_loss: 0.1982 - val_y2_output_loss: 0.5154 - val_y1_output_root_mean_squared_error: 0.4411 - val_y2_output_root_mean_squared_error: 0.7124
# Epoch 476/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.2922 - y1_output_loss: 0.1150 - y2_output_loss: 0.1756 - y1_output_root_mean_squared_error: 0.3400 - y2_output_root_mean_squared_error: 0.4203 - val_loss: 0.6966 - val_y1_output_loss: 0.1796 - val_y2_output_loss: 0.5036 - val_y1_output_root_mean_squared_error: 0.4255 - val_y2_output_root_mean_squared_error: 0.7180
# Epoch 477/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3321 - y1_output_loss: 0.1236 - y2_output_loss: 0.2082 - y1_output_root_mean_squared_error: 0.3505 - y2_output_root_mean_squared_error: 0.4574 - val_loss: 0.6874 - val_y1_output_loss: 0.1886 - val_y2_output_loss: 0.4835 - val_y1_output_root_mean_squared_error: 0.4402 - val_y2_output_root_mean_squared_error: 0.7026
# Epoch 478/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3229 - y1_output_loss: 0.1226 - y2_output_loss: 0.1988 - y1_output_root_mean_squared_error: 0.3512 - y2_output_root_mean_squared_error: 0.4467 - val_loss: 0.8657 - val_y1_output_loss: 0.2245 - val_y2_output_loss: 0.6323 - val_y1_output_root_mean_squared_error: 0.4758 - val_y2_output_root_mean_squared_error: 0.7995
# Epoch 479/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3488 - y1_output_loss: 0.1303 - y2_output_loss: 0.2164 - y1_output_root_mean_squared_error: 0.3624 - y2_output_root_mean_squared_error: 0.4664 - val_loss: 0.7743 - val_y1_output_loss: 0.1790 - val_y2_output_loss: 0.5963 - val_y1_output_root_mean_squared_error: 0.4278 - val_y2_output_root_mean_squared_error: 0.7689
# Epoch 480/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4647 - y1_output_loss: 0.1462 - y2_output_loss: 0.3181 - y1_output_root_mean_squared_error: 0.3819 - y2_output_root_mean_squared_error: 0.5647 - val_loss: 0.6909 - val_y1_output_loss: 0.1806 - val_y2_output_loss: 0.4993 - val_y1_output_root_mean_squared_error: 0.4298 - val_y2_output_root_mean_squared_error: 0.7115
# Epoch 481/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3436 - y1_output_loss: 0.1311 - y2_output_loss: 0.2131 - y1_output_root_mean_squared_error: 0.3628 - y2_output_root_mean_squared_error: 0.4605 - val_loss: 1.1498 - val_y1_output_loss: 0.3984 - val_y2_output_loss: 0.7127 - val_y1_output_root_mean_squared_error: 0.6415 - val_y2_output_root_mean_squared_error: 0.8592
# Epoch 482/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3697 - y1_output_loss: 0.1298 - y2_output_loss: 0.2373 - y1_output_root_mean_squared_error: 0.3615 - y2_output_root_mean_squared_error: 0.4889 - val_loss: 0.6932 - val_y1_output_loss: 0.1871 - val_y2_output_loss: 0.4921 - val_y1_output_root_mean_squared_error: 0.4386 - val_y2_output_root_mean_squared_error: 0.7077
# Epoch 483/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2723 - y1_output_loss: 0.1107 - y2_output_loss: 0.1608 - y1_output_root_mean_squared_error: 0.3320 - y2_output_root_mean_squared_error: 0.4025 - val_loss: 0.6877 - val_y1_output_loss: 0.1715 - val_y2_output_loss: 0.5190 - val_y1_output_root_mean_squared_error: 0.4128 - val_y2_output_root_mean_squared_error: 0.7192
# Epoch 484/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3147 - y1_output_loss: 0.1151 - y2_output_loss: 0.2002 - y1_output_root_mean_squared_error: 0.3375 - y2_output_root_mean_squared_error: 0.4481 - val_loss: 0.8215 - val_y1_output_loss: 0.1664 - val_y2_output_loss: 0.6464 - val_y1_output_root_mean_squared_error: 0.4144 - val_y2_output_root_mean_squared_error: 0.8061
# Epoch 485/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3258 - y1_output_loss: 0.1155 - y2_output_loss: 0.2083 - y1_output_root_mean_squared_error: 0.3406 - y2_output_root_mean_squared_error: 0.4581 - val_loss: 0.6595 - val_y1_output_loss: 0.1860 - val_y2_output_loss: 0.4664 - val_y1_output_root_mean_squared_error: 0.4371 - val_y2_output_root_mean_squared_error: 0.6845
# Epoch 486/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4856 - y1_output_loss: 0.1584 - y2_output_loss: 0.3235 - y1_output_root_mean_squared_error: 0.3990 - y2_output_root_mean_squared_error: 0.5714 - val_loss: 0.6409 - val_y1_output_loss: 0.1575 - val_y2_output_loss: 0.4880 - val_y1_output_root_mean_squared_error: 0.3982 - val_y2_output_root_mean_squared_error: 0.6945
# Epoch 487/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3380 - y1_output_loss: 0.1264 - y2_output_loss: 0.2220 - y1_output_root_mean_squared_error: 0.3561 - y2_output_root_mean_squared_error: 0.4596 - val_loss: 3.3248 - val_y1_output_loss: 0.8140 - val_y2_output_loss: 2.4185 - val_y1_output_root_mean_squared_error: 0.9169 - val_y2_output_root_mean_squared_error: 1.5761
# Epoch 488/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.6186 - y1_output_loss: 0.2268 - y2_output_loss: 0.3873 - y1_output_root_mean_squared_error: 0.4772 - y2_output_root_mean_squared_error: 0.6252 - val_loss: 0.6230 - val_y1_output_loss: 0.1487 - val_y2_output_loss: 0.4705 - val_y1_output_root_mean_squared_error: 0.3886 - val_y2_output_root_mean_squared_error: 0.6870
# Epoch 489/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3085 - y1_output_loss: 0.1167 - y2_output_loss: 0.1910 - y1_output_root_mean_squared_error: 0.3409 - y2_output_root_mean_squared_error: 0.4385 - val_loss: 0.6985 - val_y1_output_loss: 0.1567 - val_y2_output_loss: 0.5445 - val_y1_output_root_mean_squared_error: 0.3944 - val_y2_output_root_mean_squared_error: 0.7369
# Epoch 490/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3395 - y1_output_loss: 0.1324 - y2_output_loss: 0.2080 - y1_output_root_mean_squared_error: 0.3635 - y2_output_root_mean_squared_error: 0.4554 - val_loss: 0.8028 - val_y1_output_loss: 0.1399 - val_y2_output_loss: 0.6398 - val_y1_output_root_mean_squared_error: 0.3781 - val_y2_output_root_mean_squared_error: 0.8123
# Epoch 491/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4180 - y1_output_loss: 0.1242 - y2_output_loss: 0.2903 - y1_output_root_mean_squared_error: 0.3538 - y2_output_root_mean_squared_error: 0.5411 - val_loss: 0.6299 - val_y1_output_loss: 0.1468 - val_y2_output_loss: 0.4699 - val_y1_output_root_mean_squared_error: 0.3864 - val_y2_output_root_mean_squared_error: 0.6932
# Epoch 492/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3753 - y1_output_loss: 0.1283 - y2_output_loss: 0.2480 - y1_output_root_mean_squared_error: 0.3587 - y2_output_root_mean_squared_error: 0.4966 - val_loss: 1.2927 - val_y1_output_loss: 0.2055 - val_y2_output_loss: 1.1000 - val_y1_output_root_mean_squared_error: 0.4581 - val_y2_output_root_mean_squared_error: 1.0406
# Epoch 493/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4252 - y1_output_loss: 0.1265 - y2_output_loss: 0.2974 - y1_output_root_mean_squared_error: 0.3559 - y2_output_root_mean_squared_error: 0.5464 - val_loss: 0.7161 - val_y1_output_loss: 0.1835 - val_y2_output_loss: 0.5286 - val_y1_output_root_mean_squared_error: 0.4326 - val_y2_output_root_mean_squared_error: 0.7273
# Epoch 494/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3117 - y1_output_loss: 0.1149 - y2_output_loss: 0.1970 - y1_output_root_mean_squared_error: 0.3388 - y2_output_root_mean_squared_error: 0.4438 - val_loss: 0.7340 - val_y1_output_loss: 0.1770 - val_y2_output_loss: 0.5482 - val_y1_output_root_mean_squared_error: 0.4249 - val_y2_output_root_mean_squared_error: 0.7439
# Epoch 495/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3465 - y1_output_loss: 0.1250 - y2_output_loss: 0.2246 - y1_output_root_mean_squared_error: 0.3478 - y2_output_root_mean_squared_error: 0.4749 - val_loss: 1.0678 - val_y1_output_loss: 0.3618 - val_y2_output_loss: 0.7099 - val_y1_output_root_mean_squared_error: 0.6024 - val_y2_output_root_mean_squared_error: 0.8396
# Epoch 496/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.2907 - y1_output_loss: 0.1136 - y2_output_loss: 0.1814 - y1_output_root_mean_squared_error: 0.3357 - y2_output_root_mean_squared_error: 0.4219 - val_loss: 0.9053 - val_y1_output_loss: 0.2793 - val_y2_output_loss: 0.6214 - val_y1_output_root_mean_squared_error: 0.5356 - val_y2_output_root_mean_squared_error: 0.7864
# Epoch 497/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3537 - y1_output_loss: 0.1345 - y2_output_loss: 0.2173 - y1_output_root_mean_squared_error: 0.3667 - y2_output_root_mean_squared_error: 0.4682 - val_loss: 0.8113 - val_y1_output_loss: 0.1921 - val_y2_output_loss: 0.6176 - val_y1_output_root_mean_squared_error: 0.4423 - val_y2_output_root_mean_squared_error: 0.7847
# Epoch 498/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3254 - y1_output_loss: 0.1175 - y2_output_loss: 0.2054 - y1_output_root_mean_squared_error: 0.3443 - y2_output_root_mean_squared_error: 0.4549 - val_loss: 0.8065 - val_y1_output_loss: 0.1547 - val_y2_output_loss: 0.6580 - val_y1_output_root_mean_squared_error: 0.3957 - val_y2_output_root_mean_squared_error: 0.8062
# Epoch 499/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.4437 - y1_output_loss: 0.1465 - y2_output_loss: 0.2972 - y1_output_root_mean_squared_error: 0.3801 - y2_output_root_mean_squared_error: 0.5470 - val_loss: 0.7296 - val_y1_output_loss: 0.2261 - val_y2_output_loss: 0.5023 - val_y1_output_root_mean_squared_error: 0.4751 - val_y2_output_root_mean_squared_error: 0.7098
# Epoch 500/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3080 - y1_output_loss: 0.1162 - y2_output_loss: 0.1900 - y1_output_root_mean_squared_error: 0.3420 - y2_output_root_mean_squared_error: 0.4371 - val_loss: 0.6514 - val_y1_output_loss: 0.1712 - val_y2_output_loss: 0.4741 - val_y1_output_root_mean_squared_error: 0.4190 - val_y2_output_root_mean_squared_error: 0.6898

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 35us/sample - loss: 0.6514 - y1_output_loss: 0.1772 - y2_output_loss: 0.4815 - y1_output_root_mean_squared_error: 0.4190 - y2_output_root_mean_squared_error: 0.6898
# Loss = 0.6514191101123761, Y1_loss = 0.17723755538463593, Y1_mse = 0.41899344325065613, Y2_loss = 0.4814966320991516, Y2_mse = 0.689828634262085

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
